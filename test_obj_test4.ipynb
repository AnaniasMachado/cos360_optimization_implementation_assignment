# %%
import random
import numpy as np

from algorithms import Gradiente, Newton_1D, Newton_ND, BFGS

from objective_function_util import f, gradient_f, hessian_f

# %%
def prod(sample):
    out = 1
    for i in range(0, 5):
        out = out * sample[i] * (1 - sample[i])
    return out

def gen_sample():
    sample = []
    for i in range(0, 5):
        sample.append(random.uniform(-50000, 500000))
    while prod(sample) < 0:
        sample = []
        for i in range(0, 5):
            sample.append(random.uniform(-50000, 500000))
    return sample

# %%
samples = []

for i in range(0, 5):
    samples.append(gen_sample())

print(samples)
# Out:
# [[161629.17670167057, 287259.41346938413, 0.038171440523001365, 218636.44677386625, 106427.17767297025], [489287.7363633072, 0.8776865093459492, 282729.87819380226, 456523.4508313385, 193829.100242074], [0.3966132060158998, 261980.39502764028, 362610.94200364617, 374242.4103885531, 400438.30842256884], [123613.88920414669, 399458.39049823285, 0.05321838740201201, 68119.66138067031, 80151.17440611351], [160630.92090063746, 471247.97136833635, 0.19294318719039438, 349362.72842238424, -48578.844656194735]]

# %%
k = 100

for i in range(0, 5):
    print(f"Test for sample {i}")

    # x = np.array([0.5, 3, 8, 6, 7])
    x = samples[i]

    print("Calling gradient")
    xf = Gradiente(f, gradient_f, x, k)

    print(xf)
    print(f"Gradient result: {f(xf)}")

    print("Calling newton")
    xf = Newton_ND(f, gradient_f, hessian_f, x, k)

    print(xf)
    print(f"Newton result: {f(xf)}")

    dimensions = 5

    print("Calling BFGS")
    xf = BFGS(f, gradient_f, x, dimensions, k)

    print(xf)
    print(f"BFGS result: {f(xf)}")
# Out:
# Test for sample 0
# Calling gradient
# Armijo calls:4
# [ 1.61629177e+05  2.87259413e+05 -1.26230598e+00  2.18636447e+05
#   1.06427178e+05]
# Gradient result: nan
# Calling newton
# Nan value in matrix Hf_inv
# [1.61629177e+05 2.87259414e+05 1.03014514e+00 2.18636447e+05
#  1.06427178e+05]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-6.39646208e-07 -3.59902392e-07 -1.30047742e+00 -4.72864466e-07
#   -9.71421569e-07]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 1
# Calling gradient
# Armijo calls:4
# [4.89287736e+05 1.23041097e+00 2.82729878e+05 4.56523451e+05
#  1.93829100e+05]
# Gradient result: nan
# Calling newton
# Nan value in matrix Hf_inv
# [ 4.89287736e+05 -8.07118244e-02  2.82729878e+05  4.56523451e+05
#   1.93829100e+05]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-2.04905684e-07  3.52724463e-01 -3.54606714e-07 -2.19611600e-07
#   -5.17249444e-07]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 2
# Calling gradient
# Armijo calls:7
# [-1.72281020e-02  2.61980395e+05  3.62610942e+05  3.74242410e+05
#   4.00438308e+05]
# Gradient result: nan
# Calling newton
# Nan value in matrix Hf_inv
# [-7.72149022e-02  2.61980395e+05  3.62610942e+05  3.74242410e+05
#   4.00438308e+05]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-4.30749053e-02 -3.80587282e-07 -2.74967857e-07 -2.66421834e-07
#   -2.48993012e-07]
#  [-6.39096427e-02 -3.80674360e-07 -2.75030770e-07 -2.66482791e-07
#   -2.49049982e-07]
#  [-1.02025410e-01 -3.80873513e-07 -2.75174654e-07 -2.66622204e-07
#   -2.49180274e-07]
#  [-2.04831350e-01 -3.81443735e-07 -2.75586630e-07 -2.67021375e-07
#   -2.49553333e-07]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[2.08347373e-02 8.70781936e-11 6.29125180e-11 6.09571919e-11
#   5.69694856e-11]
#  [3.81157671e-02 1.99152569e-10 1.43884354e-10 1.39412416e-10
#   1.30292315e-10]
#  [1.02805940e-01 5.70222349e-10 4.11975977e-10 3.99171730e-10
#   3.73058657e-10]
#  [           nan            nan            nan            nan
#              nan]
#  [           nan            nan            nan            nan
#              nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 3
# Calling gradient
# Armijo calls:4
# [ 1.23613889e+05  3.99458390e+05 -8.75806323e-01  6.81196614e+04
#   8.01511744e+04]
# Gradient result: nan
# Calling newton
# Nan value in matrix Hf_inv
# [1.23613889e+05 3.99458391e+05 1.04209990e+00 6.81196616e+04
#  8.01511746e+04]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-8.47574702e-07 -2.62284421e-07 -9.29024710e-01 -1.53806329e-06
#   -1.30718278e-06]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 4
# Calling gradient
# Armijo calls:4
# [ 1.60630921e+05  4.71247971e+05 -8.99805520e-03  3.49362728e+05
#  -4.85788447e+04]
# Gradient result: nan
# Calling newton
# Nan value in matrix Hf_inv
# [ 1.60630921e+05  4.71247971e+05  1.08225997e+00  3.49362728e+05
#  -4.85788447e+04]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-6.37546763e-07 -2.17315553e-07 -2.01941242e-01 -2.93132447e-07
#    2.10808535e-06]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]
#  [nan nan nan nan nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# /var/home/pc-146/Documents/UFRJ/8° Período/Otimização/Programs/objective_function_util.py:7: RuntimeWarning: invalid value encountered in log
#   return np.sqrt(np.log(prod + 1))
# /var/home/pc-146/.conda/envs/work_env/lib/python3.12/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
