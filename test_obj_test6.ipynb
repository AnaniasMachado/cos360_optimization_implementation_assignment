# %%
import random
import numpy as np

from algorithms import Gradiente, Newton_1D, Newton_ND, BFGS

from obj_test_util6 import l, gradient_l, hessian_l

# %%
def prod(sample):
    out = 1
    for i in range(0, 5):
        out = out * sample[i] * (1 - sample[i])
    return out

def gen_sample():
    sample = []
    for i in range(0, 5):
        sample.append(random.uniform(-50000, 500000))
    while prod(sample) < 0:
        sample = []
        for i in range(0, 5):
            sample.append(random.uniform(-50000, 500000))
    return sample

# %%
samples = []

for i in range(0, 5):
    samples.append(gen_sample())

print(samples)
# Out:
# [[167096.8033534103, 0.09313363537512487, 258940.1493795602, 305804.7705429848, -32041.261615620577], [170434.49533370885, 73514.43407749578, 258124.65732796036, 4114.452432212267, 0.047084698744583875], [-13430.740290295958, 150114.27769696707, 472402.4035834539, 489933.9058444989, 0.8768472834199201], [174154.5982754179, 172993.34718941204, 293158.7875465372, 0.4403483493879321, 72075.91988296191], [488094.8492766606, 256356.59284224006, 71198.15537973352, 284743.31647901476, 0.6164251943919226]]

# %%
k = 100

for i in range(0, 5):
    print(f"Test for sample {i}")

    # x = np.array([0.5, 3, 8, 6, 7])
    x = samples[i]

    print("Calling gradient")
    xf = Gradiente(l, gradient_l, x, k)

    print(xf)
    print(f"Gradient result: {l(xf)}")

    print("Calling newton")
    xf = Newton_ND(l, gradient_l, hessian_l, x, k)

    print(xf)
    print(f"Newton result: {l(xf)}")

    dimensions = 5

    print("Calling BFGS")
    xf = BFGS(l, gradient_l, x, dimensions, k)

    print(xf)
    print(f"BFGS result: {l(xf)}")
# Out:
# Test for sample 0
# Calling gradient
# Armijo calls:12
# [ inf -inf  inf  inf -inf]
# Gradient result: nan
# Calling newton
# [ 1.67096803e+05  4.31732911e-01  2.58940149e+05  3.05804771e+05
#  -3.20412620e+04]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-1.19691457e-05 -9.63456108e+00 -7.72380748e-06 -6.54013103e-06
#    6.24185407e-05]
#  [-3.91192047e+81  6.52588682e+85 -2.52440077e+81 -2.13753539e+81
#    2.04004842e+82]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[ 3.91192047e+81 -6.52588682e+85  2.52440077e+81  2.13753539e+81
#   -2.04004842e+82]
#  [           -inf             inf            -inf            -inf
#               inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 1
# Calling gradient
# Armijo calls:12
# [ inf  inf  inf  inf -inf]
# Gradient result: nan
# Calling newton
# [1.70434495e+05 7.35144343e+04 2.58124657e+05 4.11445681e+03
#  4.70145934e-01]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-1.17347481e-05 -2.72057267e-05 -7.74820931e-06 -4.86150499e-04
#   -2.01889109e+01]
#  [-6.66824374e+76 -1.54595919e+77 -4.40290221e+76 -2.76253941e+78
#    5.50902146e+80]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[ 6.66824374e+76  1.54595919e+77  4.40290221e+76  2.76253941e+78
#   -5.50902146e+80]
#  [           -inf            -inf            -inf            -inf
#               inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 2
# Calling gradient
# Armijo calls:12
# [-inf  inf  inf  inf  inf]
# Gradient result: nan
# Calling newton
# [-1.34307407e+04  1.50114278e+05  4.72402404e+05  4.89933906e+05
#   5.07707808e-01]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[ 1.48906576e-04 -1.33232274e-05 -4.23368319e-06 -4.08218745e-06
#    6.97955008e+00]
#  [ 2.04877450e+82 -1.83311504e+81 -5.82503629e+80 -5.61659646e+80
#   -3.75799358e+85]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[-2.04877450e+82  1.83311504e+81  5.82503629e+80  5.61659646e+80
#    3.75799358e+85]
#  [            inf            -inf            -inf            -inf
#              -inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 3
# Calling gradient
# Armijo calls:12
# [ inf  inf  inf -inf  inf]
# Gradient result: nan
# Calling newton
# [-1.74151598e+05 -1.72990347e+05 -2.93155788e+05  4.76822173e-01
#  -7.20729199e+04]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-1.14840823e-05 -1.15611716e-05 -6.82225298e-06 -4.84103586e-01
#   -2.77487110e-05]
#  [-3.93331300e+75 -3.95971620e+75 -2.33663044e+75  8.15580734e+81
#   -9.50396932e+75]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[ 3.93331300e+75  3.95971620e+75  2.33663044e+75 -8.15580734e+81
#    9.50396932e+75]
#  [           -inf            -inf            -inf             inf
#              -inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 4
# Calling gradient
# Armijo calls:12
# [inf inf inf inf inf]
# Gradient result: nan
# Calling newton
# [-4.88091849e+05 -2.56353593e+05 -7.11951554e+04 -2.84740316e+05
#   5.27627490e-01]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-4.09756844e-06 -7.80164800e-06 -2.80908127e-05 -7.02388220e-06
#    9.84796538e-01]
#  [-1.57239653e+80 -2.99379606e+80 -1.07795384e+81 -2.69533704e+80
#   -8.77919070e+85]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[1.57239653e+80 2.99379606e+80 1.07795384e+81 2.69533704e+80
#   8.77919070e+85]
#  [          -inf           -inf           -inf           -inf
#             -inf]
#  [           nan            nan            nan            nan
#              nan]
#  [           nan            nan            nan            nan
#              nan]
#  [           nan            nan            nan            nan
#              nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# /var/home/pc-146/Documents/UFRJ/8° Período/Otimização/Programs/obj_test_util6.py:7: RuntimeWarning: invalid value encountered in log
#   out = out + np.log(x[i] * (1 - x[i]))
# /var/home/pc-146/Documents/UFRJ/8° Período/Otimização/Programs/penalization_fn.py:7: RuntimeWarning: overflow encountered in scalar multiply
#   out = out * x[i] * (1 - x[i])
# /var/home/pc-146/Documents/UFRJ/8° Período/Otimização/Programs/obj_test_util6.py:11: RuntimeWarning: invalid value encountered in scalar divide
#   return ((1 - 2 * x[j]) / (x[j] * (1 - x[j]))) + partial_p(x, j)
# /var/home/pc-146/Documents/UFRJ/8° Período/Otimização/Programs/algorithms.py:77: RuntimeWarning: invalid value encountered in matmul
#   d = -1 * np.matmul(Hf_inv, df(x0))
# /var/home/pc-146/.conda/envs/work_env/lib/python3.12/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
