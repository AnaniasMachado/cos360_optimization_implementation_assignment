# %%
import random
import numpy as np

from algorithms import Gradiente, Newton_1D, Newton_ND, BFGS

from obj_test_util6 import l, gradient_l, hessian_l

# %%
def prod(sample):
    out = 1
    for i in range(0, 5):
        out = out * sample[i] * (1 - sample[i])
    return out

def gen_sample():
    sample = []
    for i in range(0, 5):
        sample.append(random.uniform(-50000, 500000))
    while prod(sample) < 0:
        sample = []
        for i in range(0, 5):
            sample.append(random.uniform(-50000, 500000))
    return sample

# %%
samples = []

for i in range(0, 5):
    samples.append(gen_sample())

print(samples)
# Out:
# [[475312.29250879353, 135165.31098630227, -38813.29945000114, 0.4032208667049417, 276687.85351756], [0.7831071065520518, 261500.60243076325, 447856.6951867131, 296048.51370597957, 75057.03893965374], [97031.8581919987, 471291.5852319618, 342078.0899207266, 0.3282389878950198, -29591.005592555135], [28573.49574174873, 108814.69419887161, 348219.5944918185, 217028.660461661, 0.08774553023977205], [0.17759942408156348, 35422.80748646881, 216773.62196537573, 101811.42305702771, 89187.06228728135]]

# %%
k = 100

for i in range(0, 5):
    print(f"Test for sample {i}")

    # x = np.array([0.5, 3, 8, 6, 7])
    x = samples[i]

    print("Calling gradient")
    xf = Gradiente(l, gradient_l, x, k)

    print(xf)
    print(f"Gradient result: {l(xf)}")

    print("Calling newton")
    xf = Newton_ND(l, gradient_l, hessian_l, x, k)

    print(xf)
    print(f"Newton result: {l(xf)}")

    dimensions = 5

    print("Calling BFGS")
    xf = BFGS(l, gradient_l, x, dimensions, k)

    print(xf)
    print(f"BFGS result: {l(xf)}")
# Out:
# Test for sample 0
# Calling gradient
# Armijo calls:12
# [ inf  inf -inf -inf  inf]
# Gradient result: nan
# Calling newton
# [-4.75309293e+05 -1.35162311e+05  3.88162995e+04  4.58840573e-01
#  -2.76684854e+05]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-4.20776432e-06 -1.47967506e-05  5.15280655e-05 -8.04368576e-01
#   -7.22837518e-06]
#  [-3.01230311e+77 -1.05928694e+78  3.68885091e+78  2.29554074e+83
#   -5.17473305e+77]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[ 3.01230311e+77  1.05928694e+78 -3.68885091e+78 -2.29554074e+83
#    5.17473305e+77]
#  [           -inf            -inf             inf             inf
#              -inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 1
# Calling gradient
# Armijo calls:12
# [inf inf inf inf inf]
# Gradient result: nan
# Calling newton
# [5.10448374e-01 2.61500602e+05 4.47856695e+05 2.96048514e+05
#  7.50570390e+04]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[ 3.33360608e+00 -7.64818056e-06 -4.46571918e-06 -6.75566093e-06
#   -2.66465791e-05]
#  [-4.25633746e+87 -5.77427640e+82 -3.37155964e+82 -5.10043574e+82
#   -2.01178191e+83]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[4.25633746e+87 5.77427640e+82 3.37155964e+82 5.10043574e+82
#   2.01178191e+83]
#  [          -inf           -inf           -inf           -inf
#             -inf]
#  [           nan            nan            nan            nan
#              nan]
#  [           nan            nan            nan            nan
#              nan]
#  [           nan            nan            nan            nan
#              nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 2
# Calling gradient
# Armijo calls:12
# [ inf  inf  inf -inf -inf]
# Gradient result: nan
# Calling newton
# [-9.70288582e+04 -4.71288585e+05 -3.42075090e+05  4.13131332e-01
#   2.95940057e+04]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-2.06118933e-05 -4.24366185e-06 -5.84662679e-06 -1.55793605e+00
#    6.75869632e-05]
#  [-7.11505006e+78 -1.46487594e+78 -2.01820579e+78  4.35528041e+83
#    2.33304443e+79]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[ 7.11505006e+78  1.46487594e+78  2.01820579e+78 -4.35528041e+83
#   -2.33304443e+79]
#  [           -inf            -inf            -inf             inf
#               inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 3
# Calling gradient
# Armijo calls:12
# [ inf  inf  inf  inf -inf]
# Gradient result: nan
# Calling newton
# [2.85734962e+04 1.08814694e+05 3.48219595e+05 2.17028661e+05
#  4.25774430e-01]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-6.99961607e-05 -1.83799551e-05 -5.74351043e-06 -9.21539396e-06
#   -1.03004065e+01]
#  [-2.79775336e+81 -7.34648592e+80 -2.29568671e+80 -3.68340193e+80
#    7.47850786e+84]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[ 2.79775336e+81  7.34648592e+80  2.29568671e+80  3.68340193e+80
#   -7.47850786e+84]
#  [           -inf            -inf            -inf            -inf
#               inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
# Test for sample 4
# Calling gradient
# Armijo calls:12
# [-inf  inf  inf  inf  inf]
# Gradient result: nan
# Calling newton
# [4.77276028e-01 3.54228078e+04 2.16773622e+05 1.01811423e+05
#  8.91870624e+04]
# Newton result: nan
# Calling BFGS
# Elif.
# Nan value in matrix p or q.
# Matrix p: [[-4.41469643e+00 -5.64615956e-05 -9.22623608e-06 -1.96442576e-05
#   -2.24249029e-05]
#  [ 4.96827490e+81 -6.57015351e+77 -1.07361095e+77 -2.28590401e+77
#   -2.60947380e+77]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# Matrix q: [[-4.96827490e+81  6.57015351e+77  1.07361095e+77  2.28590401e+77
#    2.60947380e+77]
#  [            inf            -inf            -inf            -inf
#              -inf]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]
#  [            nan             nan             nan             nan
#               nan]]
# [nan nan nan nan nan]
# BFGS result: nan
